# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df1 = pd.read_csv('winequality-red 2.csv')

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]>

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X=df.drop('quality',axis=1)

# %%
y=df['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (1199, 11)

# %%
X_test.shape
# Out:
# (400, 11)

# %%
X_train.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.245315     0.665545
# volatile acidity          -0.245315          1.000000    -0.545063
# citric acid                0.665545         -0.545063     1.000000
# residual sugar             0.114762         -0.008435     0.164547
# chlorides                  0.088365          0.068815     0.220282
# free sulfur dioxide       -0.157628         -0.000124    -0.077366
# total sulfur dioxide      -0.108915          0.085511     0.033581
# density                    0.655397          0.023001     0.366664
# pH                        -0.671339          0.221270    -0.537895
# sulphates                  0.164012         -0.259959     0.306805
# alcohol                   -0.043880         -0.207526     0.110883
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114762   0.088365            -0.157628
# volatile acidity           -0.008435   0.068815            -0.000124
# citric acid                 0.164547   0.220282            -0.077366
# residual sugar              1.000000   0.046727             0.145706
# chlorides                   0.046727   1.000000            -0.001259
# free sulfur dioxide         0.145706  -0.001259             1.000000
# total sulfur dioxide        0.157754   0.039054             0.666114
# density                     0.367876   0.179720            -0.023627
# pH                         -0.077440  -0.270718             0.069827
# sulphates                   0.008435   0.377226             0.056368
# alcohol                     0.055660  -0.208625            -0.088398
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.108915  0.655397 -0.671339   0.164012
# volatile acidity                  0.085511  0.023001  0.221270  -0.259959
# citric acid                       0.033581  0.366664 -0.537895   0.306805
# residual sugar                    0.157754  0.367876 -0.077440   0.008435
# chlorides                         0.039054  0.179720 -0.270718   0.377226
# free sulfur dioxide               0.666114 -0.023627  0.069827   0.056368
# total sulfur dioxide              1.000000  0.079133 -0.071903   0.047869
# density                           0.079133  1.000000 -0.323672   0.128375
# pH                               -0.071903 -0.323672  1.000000  -0.207875
# sulphates                         0.047869  0.128375 -0.207875   1.000000
# alcohol                          -0.231689 -0.473631  0.205231   0.101661
#
#                        alcohol
# fixed acidity        -0.043880
# volatile acidity     -0.207526
# citric acid           0.110883
# residual sugar        0.055660
# chlorides            -0.208625
# free sulfur dioxide  -0.088398
# total sulfur dioxide -0.231689
# density              -0.473631
# pH                    0.205231
# sulphates             0.101661
# alcohol               1.000000

# %%
def corr(dataset,threshold):
  col_cor=set()
  corr_matrix=dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j]) > threshold:
        colname = corr_matrix.columns[i]
        col_cor.add(colname)
  return col_cor

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.97418149, -0.23260309,  1.11458849, ..., -0.78641859,
#         -1.3131938 , -1.15257747],
#        [ 0.28189382,  0.37802632,  0.09088663, ...,  0.3161036 ,
#         -0.97064635, -1.24703683],
#        [-0.71013687,  0.32251456, -1.39348108, ...,  0.70522908,
#         -0.62809889,  1.01998773],
#        ...,
#        [-0.65178213,  0.48904985, -1.08637052, ...,  1.28891729,
#         -0.68519014, -0.8691994 ],
#        [-0.2432989 , -1.84244427,  0.39799719, ...,  0.05668661,
#          0.79918216,  1.39782516],
#        [-1.46874859, -1.34283839, -0.06266865, ...,  0.51066634,
#         -0.68519014,  2.90917487]])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
def evaluate(true,predicted):
  mae = mean_absolute_error(true,predicted)
  mse = mean_squared_error(true,predicted)
  rmse = np.sqrt(mean_squared_error(true,predicted))
  r2 = r2_score(true,predicted)
  return mae,rmse,r2

# %%
models = {
    'rfb':RandomForestRegressor(),
    'ada':AdaBoostRegressor(),
    'gb' :GradientBoostingRegressor(),
    'lasso':Lasso(),
    'ridge':Ridge(),
    'linear':LinearRegression()
}

for i in range(len(list(models))):
  model = list(models.values())[i]
  model.fit(X_train,y_train)

  y_train_pred = model.predict(X_train,)
  y_test_pred  = model.predict(X_test)

  train_mae,train_rmse,train_r2 = evaluate(y_train,y_train_pred)
  test_mae,test_rmse,test_r2 = evaluate(y_test,y_test_pred)

  print(list(models.keys())[i])
  print('Model performance for Training set')
  print("- Root Mean Squared Error: {:.4f}".format(train_rmse))
  print("- Mean Absolute Error: {:.4f}".format(train_mae))
  print("- R2 Score: {:.4f}".format(train_r2))

  print('----------------------------------')

  print('Model performance for Test set')
  print("- Root Mean Squared Error: {:.4f}".format(test_rmse))
  print("- Mean Absolute Error: {:.4f}".format(test_mae))
  print("- R2 Score: {:.4f}".format(test_r2))

  print('='*35)
  print('\n')
# Out:
# rfb
# Model performance for Training set
# - Root Mean Squared Error: 0.2199
# - Mean Absolute Error: 0.1546
# - R2 Score: 0.9270
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.5610
# - Mean Absolute Error: 0.4259
# - R2 Score: 0.4912
# ===================================
#
#
# ada
# Model performance for Training set
# - Root Mean Squared Error: 0.5975
# - Mean Absolute Error: 0.4966
# - R2 Score: 0.4611
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.6149
# - Mean Absolute Error: 0.5126
# - R2 Score: 0.3888
# ===================================
#
#
# gb
# Model performance for Training set
# - Root Mean Squared Error: 0.4918
# - Mean Absolute Error: 0.3809
# - R2 Score: 0.6349
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.5967
# - Mean Absolute Error: 0.4762
# - R2 Score: 0.4245
# ===================================
#
#
# lasso
# Model performance for Training set
# - Root Mean Squared Error: 0.7965
# - Mean Absolute Error: 0.6530
# - R2 Score: 0.0424
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.7842
# - Mean Absolute Error: 0.6468
# - R2 Score: 0.0058
# ===================================
#
#
# ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.6544
# - Mean Absolute Error: 0.5009
# - R2 Score: 0.3537
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.6253
# - Mean Absolute Error: 0.5019
# - R2 Score: 0.3679
# ===================================
#
#
# linear
# Model performance for Training set
# - Root Mean Squared Error: 0.6538
# - Mean Absolute Error: 0.5002
# - R2 Score: 0.3549
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.6231
# - Mean Absolute Error: 0.4999
# - R2 Score: 0.3723
# ===================================

# %%
rf_params={
    "max_depth": [5, 8, 15, None, 10],
             "max_features": [5, 7, "auto", 8],
             "min_samples_split": [2, 8, 15, 20],
             "n_estimators": [100, 200, 500, 1000]
}
ada_params={
    "n_estimators":[50,60,70,80],
    "loss":["linear","square","exponential"]

}
grad_params={
    "loss":["huber","squared_error","absolute_error"],
    "criterion":["friedman_mse","squared_error","mse"],
    "n_estimators":[100,200,500],
    "min_samples_split":[2,8,15,20],
    "max_depth":[5,8,15,None,10]
}

# %%
randomcv_models=[
    ("rf_model",RandomForestRegressor(),rf_params),
    ("ada_model",AdaBoostRegressor(),ada_params),
    ("Grad_model",GradientBoostingRegressor(),grad_params),
]

# %%
from sklearn.model_selection import RandomizedSearchCV
model_param={}
for name,model,params in randomcv_models:
  random=RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
  random.fit(X_train,y_train)

  model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 87 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 87 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan 0.41269666 0.41177692 0.41418385        nan 0.42901139
#  0.4049394  0.39996992        nan        nan 0.3955117  0.38826802
#  0.37573127        nan 0.37024654 0.40501456 0.41383825 0.38607468
#  0.37634528 0.39532367 0.39506429 0.37382603 0.37138542 0.3991193
#  0.41004945        nan 0.3954711  0.38559617        nan 0.37351109
#         nan 0.39093641 0.3914881  0.41190215 0.39865283 0.39487336
#  0.41931537        nan 0.37327254 0.40553819 0.38759008        nan
#  0.41114287        nan 0.37902727 0.3758126         nan        nan
#  0.39446766 0.39949966 0.40138016 0.39239149 0.37612171        nan
#  0.37467193 0.39586897        nan        nan        nan 0.39700617
#  0.37180667 0.41334698 0.37552583 0.37149361        nan        nan
#  0.41137826 0.39100378 0.40242793 0.40917588 0.39814842        nan
#  0.42384994        nan 0.37203738 0.39582444 0.38866682 0.39333639
#  0.40817378        nan        nan        nan        nan 0.38628084
#  0.40366948        nan        nan 0.39692789 0.39774607 0.4135181
#  0.39764756 0.38890681        nan        nan 0.42283294 0.39469259
#  0.3745024  0.41484701 0.40087372 0.38974082]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 132 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 70 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of GradientBoostingRegressor must be a str among {'squared_error', 'friedman_mse'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 62 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of GradientBoostingRegressor must be a str among {'friedman_mse', 'squared_error'}. Got 'mse' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [ 0.37776126         nan  0.36978912  0.06510988         nan  0.35634356
#          nan  0.28172458  0.2513771   0.26973503  0.35529751         nan
#   0.28101386         nan  0.30011056         nan  0.37133943         nan
#          nan  0.35215817  0.34470145 -0.02273233  0.35407675  0.35777652
#          nan  0.35799041         nan  0.0702837   0.34760428  0.32939159
#          nan  0.35450286  0.2489993   0.35729848         nan         nan
#          nan  0.24954057  0.36767191  0.32146077         nan         nan
#   0.20614955         nan         nan         nan         nan         nan
#          nan         nan         nan  0.34490057         nan         nan
#          nan         nan         nan  0.34489759  0.35804447  0.36650277
#   0.2511829          nan  0.2027306   0.36229788         nan  0.20366711
#   0.36866854  0.36274416         nan         nan         nan         nan
#          nan  0.25785414  0.2492531          nan  0.26001618  0.26473001
#   0.28347315         nan  0.36156842  0.26187222         nan         nan
#   0.25056281  0.35600964  0.07410163  0.36514177  0.26272215  0.25792316
#   0.36889219  0.35779994  0.26792348         nan         nan  0.35594569
#  -0.02920187  0.3589324          nan         nan]
#   warnings.warn(
# ---------------- Best Params for rf_model -------------------
# {'n_estimators': 200, 'min_samples_split': 2, 'max_features': 5, 'max_depth': 15}
# ---------------- Best Params for ada_model -------------------
# {'n_estimators': 50, 'loss': 'exponential'}
# ---------------- Best Params for Grad_model -------------------
# {'n_estimators': 200, 'min_samples_split': 15, 'max_depth': 8, 'loss': 'squared_error', 'criterion': 'friedman_mse'}

# %%
models = {
    "Random Forest Regressor": RandomForestRegressor(n_estimators=200, min_samples_split=2, max_features=5, max_depth=15,
                                                     n_jobs=-1),
     "Adaboost Regressor": AdaBoostRegressor(n_estimators=50, loss='exponential'),
    "Gradient Regressor" :GradientBoostingRegressor(n_estimators=200, min_samples_split= 15, max_depth=8, loss= 'squared_error', criterion= 'friedman_mse')

}
for i in range(len(list(models))):
  model = list(models.values())[i]
  model.fit(X_train,y_train)

  y_train_pred = model.predict(X_train,)
  y_test_pred  = model.predict(X_test)

  train_mae,train_rmse,train_r2 = evaluate(y_train,y_train_pred)
  test_mae,test_rmse,test_r2 = evaluate(y_test,y_test_pred)

  print(list(models.keys())[i])
  print('Model performance for Training set')
  print("- Root Mean Squared Error: {:.4f}".format(train_rmse))
  print("- Mean Absolute Error: {:.4f}".format(train_mae))
  print("- R2 Score: {:.4f}".format(train_r2))

  print('----------------------------------')

  print('Model performance for Test set')
  print("- Root Mean Squared Error: {:.4f}".format(test_rmse))
  print("- Mean Absolute Error: {:.4f}".format(test_mae))
  print("- R2 Score: {:.4f}".format(test_r2))

  print('='*35)
  print('\n')
# Out:
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.2321
# - Mean Absolute Error: 0.1678
# - R2 Score: 0.9187
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.5502
# - Mean Absolute Error: 0.4190
# - R2 Score: 0.5107
# ===================================
#
#
# Adaboost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.5950
# - Mean Absolute Error: 0.4911
# - R2 Score: 0.4656
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.6170
# - Mean Absolute Error: 0.5112
# - R2 Score: 0.3846
# ===================================
#
#
# Gradient Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.0291
# - Mean Absolute Error: 0.0196
# - R2 Score: 0.9987
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.5870
# - Mean Absolute Error: 0.4051
# - R2 Score: 0.4429
# ===================================

# %%
scaler
# Out:
# StandardScaler()

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=200, min_samples_split=2, max_features=5, max_depth=15,
                                                     n_jobs=-1)
rf.fit(X_train_scaled,y_train)
# Out:
# RandomForestRegressor(max_depth=15, max_features=5, n_estimators=200, n_jobs=-1)

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(rf,open('rf.pkl','wb'))
